# %% [markdown]
# ### Import Libraries

# %%
# Standard Python Library
import numpy as np
import pandas as pd

# Scikit Learn library
from sklearn.impute import SimpleImputer

# Vizualization Library
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# ### Data Loading

# %%
df = pd.read_csv('athlete.csv')
print(df.shape)
# Out:
# (199462, 14)
# Name           0
# Sex            0
# Age          519
# Height      9783
# Weight     10401
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     172120
# dtype: int64

# %% [markdown]
# ### Data EDA

# %%
# Check for Duplicates
df[df.duplicated()]
#None
# Out:
# Empty DataFrame
# Columns: [Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
# Check for Nulls / Missing data
df.isna().sum()
# Out:
# Name           0
# Sex            0
# Age          519
# Height      9783
# Weight     10401
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     172120
# dtype: int64

# %%
df.describe(include='object')
# Out:
#                   Name     Sex           Team     NOC        Games  Season  \
# count           199462  199462         199462  199462       199462  199462
# unique           98432       2            461     219           28       2
# top     Andreas Wecker       M  United States     USA  2000 Summer  Summer
# freq                32  132236          11464   11959        13820  157818
#
#           City      Sport                        Event   Medal
# count   199462     199462                       199462   27342
# unique      27         51                          486       3
# top     Sydney  Athletics  Ice Hockey Men's Ice Hockey  Bronze
# freq     13820      26723                         3667    9333

# %%
df.describe().T
# Out:
#            count         mean        std     min     25%     50%     75%  \
# Age     198943.0    24.957712   5.460792    11.0    21.0    24.0    28.0
# Height  189679.0   175.451716  10.669744   127.0   168.0   175.0   183.0
# Weight  189061.0    70.726538  14.553855    25.0    60.0    70.0    80.0
# Year    199462.0  1993.352949  15.441784  1964.0  1980.0  1996.0  2006.0
#
#            max
# Age       71.0
# Height   226.0
# Weight   214.0
# Year    2016.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199462 entries, 0 to 199461
# Data columns (total 14 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    199462 non-null  object
#  1   Sex     199462 non-null  object
#  2   Age     198943 non-null  float64
#  3   Height  189679 non-null  float64
#  4   Weight  189061 non-null  float64
#  5   Team    199462 non-null  object
#  6   NOC     199462 non-null  object
#  7   Games   199462 non-null  object
#  8   Year    199462 non-null  int64
#  9   Season  199462 non-null  object
#  10  City    199462 non-null  object
#  11  Sport   199462 non-null  object
#  12  Event   199462 non-null  object
#  13  Medal   27342 non-null   object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 21.3+ MB

# %%
df[df['Age'].isna()]
# Out:
#                                     Name Sex  Age  Height  Weight      Team  \
# 99                       Mohamed Abakkar   M  NaN   156.0    48.0     Sudan
# 234                  Mohamed Abdel Fatah   M  NaN   170.0    69.0     Sudan
# 237             Ibrahim Saad Abdel Galil   M  NaN   176.0    73.0     Sudan
# 238             Ibrahim Saad Abdel Galil   M  NaN   176.0    73.0     Sudan
# 246     Hwad Ibrahim Abdel Hamid Lumomba   M  NaN   162.0    57.0     Sudan
# ...                                  ...  ..  ...     ...     ...       ...
# 195006                          Yi Yuong   M  NaN   170.0    62.0  Cambodia
# 195068                     Franois Yinga   M  NaN   176.0    66.0  Cameroon
# 195574                    Mariana Ysrael   F  NaN   173.0    56.0      Guam
# 196270                Abdel Ali Zahraoui   M  NaN   175.0    68.0   Morocco
# 198933  Mohamed Abdel Rahman Tati Zouita   M  NaN   174.0    62.0   Morocco
#
#         NOC        Games  Year  Season         City      Sport  \
# 99      SUD  1972 Summer  1972  Summer       Munich     Boxing
# 234     SUD  1972 Summer  1972  Summer       Munich   Football
# 237     SUD  1972 Summer  1972  Summer       Munich  Athletics
# 238     SUD  1972 Summer  1972  Summer       Munich  Athletics
# 246     SUD  1968 Summer  1968  Summer  Mexico City     Boxing
# ...     ...          ...   ...     ...          ...        ...
# 195006  CAM  1964 Summer  1964  Summer        Tokyo    Cycling
# 195068  CMR  1988 Summer  1988  Summer        Seoul  Wrestling
# 195574  GUM  1988 Summer  1988  Summer        Seoul  Athletics
# 196270  MAR  1972 Summer  1972  Summer       Munich   Football
# 198933  MAR  1972 Summer  1972  Summer       Munich   Football
#
#                                                Event Medal
# 99                            Boxing Men's Flyweight   NaN
# 234                          Football Men's Football   NaN
# 237                       Athletics Men's 200 metres   NaN
# 238             Athletics Men's 4 x 400 metres Relay   NaN
# 246                       Boxing Men's Featherweight   NaN
# ...                                              ...   ...
# 195006  Cycling Men's 100 kilometres Team Time Trial   NaN
# 195068      Wrestling Men's Featherweight, Freestyle   NaN
# 195574                    Athletics Women's Marathon   NaN
# 196270                       Football Men's Football   NaN
# 198933                       Football Men's Football   NaN
#
# [519 rows x 14 columns]

# %%
df[df['Height'].isna()]
# Out:
#                                Name Sex   Age  Height  Weight          Team  \
# 56                 Nils Egil Aaness   M  27.0     NaN     NaN        Norway
# 58                    Johan Aantjes   M  26.0     NaN     NaN   Netherlands
# 61             Willemien Aardenburg   F  22.0     NaN     NaN   Netherlands
# 80                 Abdelhak Aatakni   M  24.0     NaN    64.0       Morocco
# 97                   M'Bairo Abakar   M  31.0     NaN     NaN          Chad
# ...                             ...  ..   ...     ...     ...           ...
# 199310  Vladimir Anatolyevich Zuyev   M  35.0     NaN     NaN       Belarus
# 199321         Irina Lvovna Zuykova   F  34.0     NaN     NaN  Unified Team
# 199322         Irina Lvovna Zuykova   F  34.0     NaN     NaN  Unified Team
# 199333                 Denis vegelj   M  20.0     NaN     NaN      Slovenia
# 199334                 Denis vegelj   M  24.0     NaN     NaN      Slovenia
#
#         NOC        Games  Year  Season         City          Sport  \
# 56      NOR  1964 Winter  1964  Winter    Innsbruck  Speed Skating
# 58      NED  1984 Summer  1984  Summer  Los Angeles     Water Polo
# 61      NED  1988 Summer  1988  Summer        Seoul         Hockey
# 80      MAR  2012 Summer  2012  Summer       London         Boxing
# 97      CHA  1992 Summer  1992  Summer    Barcelona           Judo
# ...     ...          ...   ...     ...          ...            ...
# 199310  BLR  1996 Summer  1996  Summer      Atlanta        Sailing
# 199321  EUN  1992 Summer  1992  Summer    Barcelona  Equestrianism
# 199322  EUN  1992 Summer  1992  Summer    Barcelona  Equestrianism
# 199333  SLO  1992 Summer  1992  Summer    Barcelona         Rowing
# 199334  SLO  1996 Summer  1996  Summer      Atlanta         Rowing
#
#                                            Event   Medal
# 56              Speed Skating Men's 1,500 metres     NaN
# 58                   Water Polo Men's Water Polo     NaN
# 61                         Hockey Women's Hockey  Bronze
# 80               Boxing Men's Light-Welterweight     NaN
# 97                  Judo Men's Half-Middleweight     NaN
# ...                                          ...     ...
# 199310         Sailing Mixed Two Person Keelboat     NaN
# 199321  Equestrianism Mixed Dressage, Individual     NaN
# 199322        Equestrianism Mixed Dressage, Team     NaN
# 199333                Rowing Men's Coxless Pairs  Bronze
# 199334                Rowing Men's Coxless Fours     NaN
#
# [9783 rows x 14 columns]

# %%
df[df['Weight'].isna()]
# Out:
#                                Name Sex   Age  Height  Weight          Team  \
# 52        Ragnhild Margrethe Aamodt   F  27.0   163.0     NaN        Norway
# 56                 Nils Egil Aaness   M  27.0     NaN     NaN        Norway
# 58                    Johan Aantjes   M  26.0     NaN     NaN   Netherlands
# 61             Willemien Aardenburg   F  22.0     NaN     NaN   Netherlands
# 97                   M'Bairo Abakar   M  31.0     NaN     NaN          Chad
# ...                             ...  ..   ...     ...     ...           ...
# 199310  Vladimir Anatolyevich Zuyev   M  35.0     NaN     NaN       Belarus
# 199321         Irina Lvovna Zuykova   F  34.0     NaN     NaN  Unified Team
# 199322         Irina Lvovna Zuykova   F  34.0     NaN     NaN  Unified Team
# 199333                 Denis vegelj   M  20.0     NaN     NaN      Slovenia
# 199334                 Denis vegelj   M  24.0     NaN     NaN      Slovenia
#
#         NOC        Games  Year  Season         City          Sport  \
# 52      NOR  2008 Summer  2008  Summer      Beijing       Handball
# 56      NOR  1964 Winter  1964  Winter    Innsbruck  Speed Skating
# 58      NED  1984 Summer  1984  Summer  Los Angeles     Water Polo
# 61      NED  1988 Summer  1988  Summer        Seoul         Hockey
# 97      CHA  1992 Summer  1992  Summer    Barcelona           Judo
# ...     ...          ...   ...     ...          ...            ...
# 199310  BLR  1996 Summer  1996  Summer      Atlanta        Sailing
# 199321  EUN  1992 Summer  1992  Summer    Barcelona  Equestrianism
# 199322  EUN  1992 Summer  1992  Summer    Barcelona  Equestrianism
# 199333  SLO  1992 Summer  1992  Summer    Barcelona         Rowing
# 199334  SLO  1996 Summer  1996  Summer      Atlanta         Rowing
#
#                                            Event   Medal
# 52                     Handball Women's Handball    Gold
# 56              Speed Skating Men's 1,500 metres     NaN
# 58                   Water Polo Men's Water Polo     NaN
# 61                         Hockey Women's Hockey  Bronze
# 97                  Judo Men's Half-Middleweight     NaN
# ...                                          ...     ...
# 199310         Sailing Mixed Two Person Keelboat     NaN
# 199321  Equestrianism Mixed Dressage, Individual     NaN
# 199322        Equestrianism Mixed Dressage, Team     NaN
# 199333                Rowing Men's Coxless Pairs  Bronze
# 199334                Rowing Men's Coxless Fours     NaN
#
# [10401 rows x 14 columns]

# %%
df[df['Medal'].isna()]
# Out:
#                             Name Sex   Age  Height  Weight         Team  NOC  \
# 0                      A Dijiang   M  24.0   180.0    80.0        China  CHN
# 1                       A Lamusi   M  23.0   170.0    60.0        China  CHN
# 2       Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 3       Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 4       Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# ...                          ...  ..   ...     ...     ...          ...  ...
# 199457                Andrzej ya   M  29.0   179.0    89.0     Poland-1  POL
# 199458                  Piotr ya   M  27.0   176.0    59.0       Poland  POL
# 199459                  Piotr ya   M  27.0   176.0    59.0       Poland  POL
# 199460        Tomasz Ireneusz ya   M  30.0   185.0    96.0       Poland  POL
# 199461        Tomasz Ireneusz ya   M  34.0   185.0    96.0       Poland  POL
#
#               Games  Year  Season            City          Sport  \
# 0       1992 Summer  1992  Summer       Barcelona     Basketball
# 1       2012 Summer  2012  Summer          London           Judo
# 2       1988 Winter  1988  Winter         Calgary  Speed Skating
# 3       1988 Winter  1988  Winter         Calgary  Speed Skating
# 4       1992 Winter  1992  Winter     Albertville  Speed Skating
# ...             ...   ...     ...             ...            ...
# 199457  1976 Winter  1976  Winter       Innsbruck           Luge
# 199458  2014 Winter  2014  Winter           Sochi    Ski Jumping
# 199459  2014 Winter  2014  Winter           Sochi    Ski Jumping
# 199460  1998 Winter  1998  Winter          Nagano      Bobsleigh
# 199461  2002 Winter  2002  Winter  Salt Lake City      Bobsleigh
#
#                                            Event Medal
# 0                    Basketball Men's Basketball   NaN
# 1                   Judo Men's Extra-Lightweight   NaN
# 2               Speed Skating Women's 500 metres   NaN
# 3             Speed Skating Women's 1,000 metres   NaN
# 4               Speed Skating Women's 500 metres   NaN
# ...                                          ...   ...
# 199457                Luge Mixed (Men)'s Doubles   NaN
# 199458  Ski Jumping Men's Large Hill, Individual   NaN
# 199459        Ski Jumping Men's Large Hill, Team   NaN
# 199460                      Bobsleigh Men's Four   NaN
# 199461                      Bobsleigh Men's Four   NaN
#
# [172120 rows x 14 columns]

# %% [markdown]
# ### Replace Nulls using Scikit Learn Simple Imputer

# %%
# get the categorical and numeric column names
obj_col = list(df.select_dtypes(include='object').columns)
num_col = list(df.select_dtypes(include=['float64','int64']).columns)
print(f'The object columns are: {obj_col} \nThe numeric columns are: {num_col}')
# Out:
# The object columns are: ['Name', 'Sex', 'Team', 'NOC', 'Games', 'Season', 'City', 'Sport', 'Event', 'Medal']
# The numeric columns are: ['Age', 'Height', 'Weight', 'Year']

# %%
# Get the dataframe of the numeric and objects
df_obj = df.select_dtypes(include='object')
df_num = df.select_dtypes(exclude='object')

# %%
# Simple Imputer for the Numeric
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
imp_mean.fit(df_num)
#imp_mean.get_params()
# Out:
# SimpleImputer()

# %%
# Prepare the numerica Data
nums = pd.DataFrame(data = imp_mean.transform(df_num), columns=num_col)
nums.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199462 entries, 0 to 199461
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Age     199462 non-null  float64
#  1   Height  199462 non-null  float64
#  2   Weight  199462 non-null  float64
#  3   Year    199462 non-null  float64
# dtypes: float64(4)
# memory usage: 6.1 MB

# %%
# Simple Imputer for the category
imp_miss = SimpleImputer(missing_values=np.nan, strategy='constant', fill_value='None')
imp_miss.fit(df_obj)
# Out:
# SimpleImputer(fill_value='None', strategy='constant')

# %%
# prepare the category data
obj = pd.DataFrame(data = imp_miss.transform(df_obj), columns=obj_col)
obj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199462 entries, 0 to 199461
# Data columns (total 10 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    199462 non-null  object
#  1   Sex     199462 non-null  object
#  2   Team    199462 non-null  object
#  3   NOC     199462 non-null  object
#  4   Games   199462 non-null  object
#  5   Season  199462 non-null  object
#  6   City    199462 non-null  object
#  7   Sport   199462 non-null  object
#  8   Event   199462 non-null  object
#  9   Medal   199462 non-null  object
# dtypes: object(10)
# memory usage: 15.2+ MB

# %% [markdown]
# ### Joining the two cleaned data

# %%
data = nums.join(obj)
data
# Out:
#          Age  Height  Weight    Year                      Name Sex  \
# 0       24.0   180.0    80.0  1992.0                 A Dijiang   M
# 1       23.0   170.0    60.0  2012.0                  A Lamusi   M
# 2       21.0   185.0    82.0  1988.0  Christine Jacoba Aaftink   F
# 3       21.0   185.0    82.0  1988.0  Christine Jacoba Aaftink   F
# 4       25.0   185.0    82.0  1992.0  Christine Jacoba Aaftink   F
# ...      ...     ...     ...     ...                       ...  ..
# 199457  29.0   179.0    89.0  1976.0                Andrzej ya   M
# 199458  27.0   176.0    59.0  2014.0                  Piotr ya   M
# 199459  27.0   176.0    59.0  2014.0                  Piotr ya   M
# 199460  30.0   185.0    96.0  1998.0        Tomasz Ireneusz ya   M
# 199461  34.0   185.0    96.0  2002.0        Tomasz Ireneusz ya   M
#
#                Team  NOC        Games  Season            City          Sport  \
# 0             China  CHN  1992 Summer  Summer       Barcelona     Basketball
# 1             China  CHN  2012 Summer  Summer          London           Judo
# 2       Netherlands  NED  1988 Winter  Winter         Calgary  Speed Skating
# 3       Netherlands  NED  1988 Winter  Winter         Calgary  Speed Skating
# 4       Netherlands  NED  1992 Winter  Winter     Albertville  Speed Skating
# ...             ...  ...          ...     ...             ...            ...
# 199457     Poland-1  POL  1976 Winter  Winter       Innsbruck           Luge
# 199458       Poland  POL  2014 Winter  Winter           Sochi    Ski Jumping
# 199459       Poland  POL  2014 Winter  Winter           Sochi    Ski Jumping
# 199460       Poland  POL  1998 Winter  Winter          Nagano      Bobsleigh
# 199461       Poland  POL  2002 Winter  Winter  Salt Lake City      Bobsleigh
#
#                                            Event Medal
# 0                    Basketball Men's Basketball  None
# 1                   Judo Men's Extra-Lightweight  None
# 2               Speed Skating Women's 500 metres  None
# 3             Speed Skating Women's 1,000 metres  None
# 4               Speed Skating Women's 500 metres  None
# ...                                          ...   ...
# 199457                Luge Mixed (Men)'s Doubles  None
# 199458  Ski Jumping Men's Large Hill, Individual  None
# 199459        Ski Jumping Men's Large Hill, Team  None
# 199460                      Bobsleigh Men's Four  None
# 199461                      Bobsleigh Men's Four  None
#
# [199462 rows x 14 columns]

# %%
# Converting Age to Integer
data['Age'] = data['Age'].astype('int')

# %% [markdown]
# ## Exporting the clean data for SQL modeling

# %%
data.to_csv('clean_athlete.csv')
